# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_10 = pd.read_csv("..\\Cleaned_Data\\2010_Data_Binning_Clean.csv")
data_15 = pd.read_csv("..\\Cleaned_Data\\2015_Data_Binning_Clean.csv")
data_19 = pd.read_csv("..\\Cleaned_Data\\2019_Data_Binning_Clean.csv")

# %%
data.head()
# Out:
#    Unnamed: 0       County_Name State_Name  \
# 0           0    Baldwin County    Alabama
# 1           4    Houston County    Alabama
# 2           5  Jefferson County    Alabama
# 3           7    Madison County    Alabama
# 4           8     Mobile County    Alabama
#
#   Civilian employed population 16 years and over_2010  \
# 0                                             77,263
# 1                                             45,470
# 2                                            289,454
# 3                                            156,411
# 4                                            170,552
#
#   Agriculture, forestry, fishing and hunting, and mining_2010  \
# 0                                              1,302
# 1                                                790
# 2                                              1,761
# 3                                                569
# 4                                              2,025
#
# ...

# %%
# Remove ',' from String literals in DataFrame
data_10['Civilian employed population 16 years and over_2010'] = data['Civilian employed population 16 years and over_2010'].str.replace(',','')
data_10['Agriculture, forestry, fishing and hunting, and mining_2010'] = data['Agriculture, forestry, fishing and hunting, and mining_2010'].str.replace(',','')
data_10['Construction_2010'] = data['Construction_2010'].str.replace(',','')
data_10['Manufacturing_2010'] = data['Manufacturing_2010'].str.replace(',','')
data_10['Wholesale trade_2010'] = data['Wholesale trade_2010'].str.replace(',','')
data_10['Retail trade_2010'] = data['Retail trade_2010'].str.replace(',','')
data_10['Transportation and warehousing, and utilities_2010'] = data['Transportation and warehousing, and utilities_2010'].str.replace(',','')
data_10['Information_2010'] = data['Information_2010'].str.replace(',','')
data_10['Finance and insurance, and real estate and rental and leasing_2010'] = data['Finance and insurance, and real estate and rental and leasing_2010'].str.replace(',','')
data_10['Professional, scientific, and management, and administrative and waste management services_2010'] = data['Professional, scientific, and management, and administrative and waste management services_2010'].str.replace(',','')
data_10['Educational services, and health care and social assistance_2010'] = data['Educational services, and health care and social assistance_2010'].str.replace(',','')
data_10['Arts, entertainment, and recreation, and accommodation and food services_2010'] = data['Arts, entertainment, and recreation, and accommodation and food services_2010'].str.replace(',','')
data_10['Other services, except public administration_2010'] = data['Other services, except public administration_2010'].str.replace(',','')
data_10['Public administration_2010'] = data['Public administration_2010'].str.replace(',','')

data_15['Civilian employed population 16 years and over_2015'] = data['Civilian employed population 16 years and over_2015'].str.replace(',','')
data_15'Agriculture, forestry, fishing and hunting, and mining_2015'] = data['Agriculture, forestry, fishing and hunting, and mining_2015'].str.replace(',','')
data_15['Construction_2015'] = data['Construction_2015'].str.replace(',','')
data_15['Manufacturing_2015'] = data['Manufacturing_2015'].str.replace(',','')
data_15['Wholesale trade_2015'] = data['Wholesale trade_2015'].str.replace(',','')
data_15['Retail trade_2015'] = data['Retail trade_2015'].str.replace(',','')
data_15['Transportation and warehousing, and utilities_2015'] = data['Transportation and warehousing, and utilities_2015'].str.replace(',','')
data_15['Information_2015'] = data['Information_2015'].str.replace(',','')
data_15['Finance and insurance, and real estate and rental and leasing_2015'] = data['Finance and insurance, and real estate and rental and leasing_2015'].str.replace(',','')
data_15['Professional, scientific, and management, and administrative and waste management services_2015'] = data['Professional, scientific, and management, and administrative and waste management services_2015'].str.replace(',','')
data_15['Educational services, and health care and social assistance_2015'] = data['Educational services, and health care and social assistance_2015'].str.replace(',','')
data_15['Arts, entertainment, and recreation, and accommodation and food services_2015'] = data['Arts, entertainment, and recreation, and accommodation and food services_2015'].str.replace(',','')
data_15['Other services, except public administration_2015'] = data['Other services, except public administration_2015'].str.replace(',','')
data_15['Public administration_2015'] = data['Public administration_2015'].str.replace(',','')

data_19['Civilian employed population 16 years and over_2019'] = data['Civilian employed population 16 years and over_2019'].str.replace(',','')
data_19['Agriculture, forestry, fishing and hunting, and mining_2019'] = data['Agriculture, forestry, fishing and hunting, and mining_2019'].str.replace(',','')
data_19['Construction_2019'] = data['Construction_2019'].str.replace(',','')
data_19['Manufacturing_2019'] = data['Manufacturing_2019'].str.replace(',','')
data_19['Wholesale trade_2019'] = data['Wholesale trade_2019'].str.replace(',','')
data_19['Retail trade_2019'] = data['Retail trade_2019'].str.replace(',','')
data_19['Transportation and warehousing, and utilities_2019'] = data['Transportation and warehousing, and utilities_2019'].str.replace(',','')
data_19['Information_2019'] = data['Information_2019'].str.replace(',','')
data_19['Finance and insurance, and real estate and rental and leasing_2019'] = data['Finance and insurance, and real estate and rental and leasing_2019'].str.replace(',','')
data_19['Professional, scientific, and management, and administrative and waste management services_2019'] = data['Professional, scientific, and management, and administrative and waste management services_2019'].str.replace(',','')
data_19['Educational services, and health care and social assistance_2019'] = data['Educational services, and health care and social assistance_2019'].str.replace(',','')
data_19['Arts, entertainment, and recreation, and accommodation and food services_2019'] = data['Arts, entertainment, and recreation, and accommodation and food services_2019'].str.replace(',','')
data_19['Other services, except public administration_2019'] = data['Other services, except public administration_2019'].str.replace(',','')
data_19['Public administration_2019'] = data['Public administration_2019'].str.replace(',','')

# %%
# Remove industry_2010 column
del data_10['Industry_2010']
del data_10['County_Name']
del data_10['State_Name']

del data_15['Industry_2015']
del data_15['County_Name']
del data_15['State_Name']

del data_19['Industry_2019']
del data_19['County_Name']
del data_19['State_Name']

# %%
data_10.head()
# Out:
#    Unnamed: 0 Civilian employed population 16 years and over_2010  \
# 0           0                                              77263
# 1           4                                              45470
# 2           5                                             289454
# 3           7                                             156411
# 4           8                                             170552
#
#   Agriculture, forestry, fishing and hunting, and mining_2010  \
# 0                                               1302
# 1                                                790
# 2                                               1761
# 3                                                569
# 4                                               2025
#
#   Construction_2010 Manufacturing_2010 Wholesale trade_2010 Retail trade_2010  \
# 0              6489               6134                 2131              9525
# 1              2967               4237                 1897              6225
# ...

# %%
# Convert values in data to integer type for ML
data_10new = data.copy()
data_10new = data_10new.astype(int)

data_15new = data.copy()
data_15new = data_15new.astype(int)

data_19new = data.copy()
data_19new = data_19new.astype(int)

# %%
# Convert values in data_2010 to proportion of total employed
data_10new['Agriculture, forestry, fishing and hunting, and mining_2010'] = (data_new['Agriculture, forestry, fishing and hunting, and mining_2010']/data_new['Civilian employed population 16 years and over_2010'])*100
data_10new['Construction_2010'] = (data_new['Construction_2010']/data_new['Civilian employed population 16 years and over_2010'])*100
data_10new['Manufacturing_2010'] = (data_new['Manufacturing_2010']/data_new['Civilian employed population 16 years and over_2010'])*100
data_10new['Wholesale trade_2010'] = (data_new['Wholesale trade_2010']/data_new['Civilian employed population 16 years and over_2010'])*100
data_10new['Retail trade_2010'] = (data_new['Retail trade_2010']/data_new['Civilian employed population 16 years and over_2010'])*100
data_10new['Transportation and warehousing, and utilities_2010'] = (data_new['Transportation and warehousing, and utilities_2010']/data_new['Civilian employed population 16 years and over_2010'])*100
data_10new['Information_2010'] = (data_new['Information_2010']/data_new['Civilian employed population 16 years and over_2010'])*100
data_10new['Finance and insurance, and real estate and rental and leasing_2010'] = (data_new['Finance and insurance, and real estate and rental and leasing_2010']/data_new['Civilian employed population 16 years and over_2010'])*100
data_10new['Professional, scientific, and management, and administrative and waste management services_2010'] = (data_new['Professional, scientific, and management, and administrative and waste management services_2010']/data_new['Civilian employed population 16 years and over_2010'])*100
data_10new['Educational services, and health care and social assistance_2010'] = (data_new['Educational services, and health care and social assistance_2010']/data_new['Civilian employed population 16 years and over_2010'])*100
data_10new['Arts, entertainment, and recreation, and accommodation and food services_2010'] = (data_new['Arts, entertainment, and recreation, and accommodation and food services_2010']/data_new['Civilian employed population 16 years and over_2010'])*100
data_10new['Other services, except public administration_2010'] = (data_new['Other services, except public administration_2010']/data_new['Civilian employed population 16 years and over_2010'])*100
data_10new['Public administration_2010'] = (data_new['Public administration_2010']/data_new['Civilian employed population 16 years and over_2010'])*100

# Convert values in data_2015 to proportion of total employed
data_15new['Agriculture, forestry, fishing and hunting, and mining_2015'] = (data_new['Agriculture, forestry, fishing and hunting, and mining_2015']/data_new['Civilian employed population 16 years and over_2015'])*100
data_15new['Construction_2015'] = (data_new['Construction_2015']/data_new['Civilian employed population 16 years and over_2015'])*100
data_15new['Manufacturing_2015'] = (data_new['Manufacturing_2015']/data_new['Civilian employed population 16 years and over_2015'])*100
data_15new['Wholesale trade_2015'] = (data_new['Wholesale trade_2015']/data_new['Civilian employed population 16 years and over_2015'])*100
data_15new['Retail trade_2015'] = (data_new['Retail trade_2015']/data_new['Civilian employed population 16 years and over_2015'])*100
data_15new['Transportation and warehousing, and utilities_2015'] = (data_new['Transportation and warehousing, and utilities_2015']/data_new['Civilian employed population 16 years and over_2015'])*100
data_15new['Information_2015'] = (data_new['Information_2015']/data_new['Civilian employed population 16 years and over_2015'])*100
data_15new['Finance and insurance, and real estate and rental and leasing_2015'] = (data_new['Finance and insurance, and real estate and rental and leasing_2015']/data_new['Civilian employed population 16 years and over_2015'])*100
data_15new['Professional, scientific, and management, and administrative and waste management services_2015'] = (data_new['Professional, scientific, and management, and administrative and waste management services_2015']/data_new['Civilian employed population 16 years and over_2015'])*100
data_15new['Educational services, and health care and social assistance_2015'] = (data_new['Educational services, and health care and social assistance_2015']/data_new['Civilian employed population 16 years and over_2015'])*100
data_15new['Arts, entertainment, and recreation, and accommodation and food services_2015'] = (data_new['Arts, entertainment, and recreation, and accommodation and food services_2015']/data_new['Civilian employed population 16 years and over_2015'])*100
data_15new['Other services, except public administration_2015'] = (data_new['Other services, except public administration_2015']/data_new['Civilian employed population 16 years and over_2015'])*100
data_15new['Public administration_2015'] = (data_new['Public administration_2015']/data_new['Civilian employed population 16 years and over_2015'])*100

# Convert values in data_2019 to proportion of total employed
data_19new['Agriculture, forestry, fishing and hunting, and mining_2019'] = (data_19new['Agriculture, forestry, fishing and hunting, and mining_2019']/data_new['Civilian employed population 16 years and over_2019'])*100
data_19new['Construction_2019'] = (data_19new['Construction_2019']/data_new['Civilian employed population 16 years and over_2019'])*100
data_19new['Manufacturing_2019'] = (data_19new['Manufacturing_2019']/data_new['Civilian employed population 16 years and over_2019'])*100
data_19new['Wholesale trade_2019'] = (data_19new['Wholesale trade_2019']/data_new['Civilian employed population 16 years and over_2019'])*100
data_19new['Retail trade_2019'] = (data_19new['Retail trade_2019']/data_new['Civilian employed population 16 years and over_2019'])*100
data_19new['Transportation and warehousing, and utilities_2019'] = (data_19new['Transportation and warehousing, and utilities_2019']/data_new['Civilian employed population 16 years and over_2019'])*100
data_19new['Information_2019'] = (data_19neww['Information_2019']/data_new['Civilian employed population 16 years and over_2019'])*100
data_19new['Finance and insurance, and real estate and rental and leasing_2019'] = (data_19new['Finance and insurance, and real estate and rental and leasing_2019']/data_new['Civilian employed population 16 years and over_2019'])*100
data_19new['Professional, scientific, and management, and administrative and waste management services_2019'] = (data_19new['Professional, scientific, and management, and administrative and waste management services_2019']/data_new['Civilian employed population 16 years and over_2019'])*100
data_19new['Educational services, and health care and social assistance_2019'] = (data_19new['Educational services, and health care and social assistance_2019']/data_new['Civilian employed population 16 years and over_2019'])*100
data_19new['Arts, entertainment, and recreation, and accommodation and food services_2019'] = (data_19new['Arts, entertainment, and recreation, and accommodation and food services_2019']/data_new['Civilian employed population 16 years and over_2019'])*100
data_19new['Other services, except public administration_2019'] = (data_19new['Other services, except public administration_2019']/data_new['Civilian employed population 16 years and over_2019'])*100
data_19new['Public administration_2019'] = (data_19new['Public administration_2019']/data_new['Civilian employed population 16 years and over_2019'])*100

# %%
data_new.columns
# Out:
# Index(['Unnamed: 0', 'Civilian employed population 16 years and over_2010',
#        'Agriculture, forestry, fishing and hunting, and mining_2010',
#        'Construction_2010', 'Manufacturing_2010', 'Wholesale trade_2010',
#        'Retail trade_2010',
#        'Transportation and warehousing, and utilities_2010',
#        'Information_2010',
#        'Finance and insurance, and real estate and rental and leasing_2010',
#        'Professional, scientific, and management, and administrative and waste management services_2010',
#        'Educational services, and health care and social assistance_2010',
#        'Arts, entertainment, and recreation, and accommodation and food services_2010',
#        'Other services, except public administration_2010',
#        'Public administration_2010',
#        'Civilian employed population 16 years and over_2015',
#        'Agriculture, forestry, fishing and hunting, and mining_2015',
# ...

# %%
x = data_new[['Agriculture, forestry, fishing and hunting, and mining_2010','Construction_2010','Manufacturing_2010','Wholesale trade_2010','Transportation and warehousing, and utilities_2010','Information_2010','Finance and insurance, and real estate and rental and leasing_2010','Arts, entertainment, and recreation, and accommodation and food services_2010','Public administration_2010']]
y = data_new['2010_Binning']

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
print(vif_data)
# Out:
#                                              feature        VIF
# 0  Agriculture, forestry, fishing and hunting, an...   1.731309
# 1                                  Construction_2010  15.307149
# 2                                 Manufacturing_2010   5.013864
# 3                               Wholesale trade_2010  12.464467
# 4  Transportation and warehousing, and utilities_...  10.815233
# 5                                   Information_2010   7.927940
# 6  Finance and insurance, and real estate and ren...  10.334596
# 7  Arts, entertainment, and recreation, and accom...   9.397590
# 8                         Public administration_2010   4.384701

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=100)

from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=2, random_state=2)
clf.fit(x_train, y_train)

#Prediction of test set
y_pred= clf.predict(x_test)

from sklearn import metrics
meanAbErr = metrics.mean_absolute_error(y_test, y_pred)
meanSqErr = metrics.mean_squared_error(y_test, y_pred)
rootMeanSqErr = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('R squared: {:.2f}'.format(clf.score(x_test,y_test)))
print('Mean Absolute Error:', meanAbErr)
print('Mean Square Error:', meanSqErr)
print('Root Mean Square Error:', rootMeanSqErr)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# R squared: 0.74
# Mean Absolute Error: 0.2847222222222222
# Mean Square Error: 0.3402777777777778
# Root Mean Square Error: 0.5833333333333334
# Accuracy: 0.7430555555555556

# %%
from sklearn.tree import export_text
x1 = ['Agriculture, forestry, fishing and hunting, and mining_2010','Construction_2010','Manufacturing_2010','Wholesale trade_2010','Transportation and warehousing, and utilities_2010','Information_2010','Finance and insurance, and real estate and rental and leasing_2010', 'Arts, entertainment, and recreation, and accommodation and food services_2010','Public administration_2010']

tree_rules = export_text(clf, feature_names=x1)
print(tree_rules)
# Out:
# |--- Agriculture, forestry, fishing and hunting, and mining_2010 <= 12.05
# |   |--- Information_2010 <= 4.29
# |   |   |--- class: 2
# |   |--- Information_2010 >  4.29
# |   |   |--- class: 3
# |--- Agriculture, forestry, fishing and hunting, and mining_2010 >  12.05
# |   |--- Wholesale trade_2010 <= 3.23
# |   |   |--- class: 4
# |   |--- Wholesale trade_2010 >  3.23
# |   |   |--- class: 3

# %%
from sklearn.metrics import classification_report

# Print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        15
#            2       0.76      0.97      0.85       109
#            3       0.33      0.05      0.09        19
#            4       0.00      0.00      0.00         1
#
#     accuracy                           0.74       144
#    macro avg       0.27      0.26      0.24       144
# weighted avg       0.62      0.74      0.66       144
# C:\Users\danan\anaconda3\envs\mlenv\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
x = data_new[['Agriculture, forestry, fishing and hunting, and mining_2015','Construction_2015','Manufacturing_2015','Wholesale trade_2015','Transportation and warehousing, and utilities_2015','Information_2015','Finance and insurance, and real estate and rental and leasing_2015', 'Arts, entertainment, and recreation, and accommodation and food services_2015','Public administration_2015']]
y = data_new['2015_Binning']

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
print(vif_data)
# Out:
#                                              feature        VIF
# 0  Agriculture, forestry, fishing and hunting, an...   1.695608
# 1                                  Construction_2015  13.426208
# 2                                 Manufacturing_2015   4.310339
# 3                               Wholesale trade_2015  13.425963
# 4  Transportation and warehousing, and utilities_...   9.521292
# 5                                   Information_2015   7.411636
# 6  Finance and insurance, and real estate and ren...  10.830502
# 7  Arts, entertainment, and recreation, and accom...  10.907259
# 8                         Public administration_2015   4.507879

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=100)

from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=2, random_state=2)
clf.fit(x_train, y_train)

#Prediction of test set
y_pred= clf.predict(x_test)

from sklearn import metrics
meanAbErr = metrics.mean_absolute_error(y_test, y_pred)
meanSqErr = metrics.mean_squared_error(y_test, y_pred)
rootMeanSqErr = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('R squared: {:.2f}'.format(clf.score(x_test,y_test)))
print('Mean Absolute Error:', meanAbErr)
print('Mean Square Error:', meanSqErr)
print('Root Mean Square Error:', rootMeanSqErr)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# R squared: 0.83
# Mean Absolute Error: 0.20833333333333334
# Mean Square Error: 0.3055555555555556
# Root Mean Square Error: 0.5527707983925667
# Accuracy: 0.8333333333333334

# %%
from sklearn.tree import export_text
x1 = ['Agriculture, forestry, fishing and hunting, and mining_2015','Construction_2015','Manufacturing_2015','Wholesale trade_2015','Transportation and warehousing, and utilities_2015','Information_2015','Finance and insurance, and real estate and rental and leasing_2015', 'Arts, entertainment, and recreation, and accommodation and food services_2015','Public administration_2015']

tree_rules = export_text(clf, feature_names=x1)
print(tree_rules)
# Out:
# |--- Agriculture, forestry, fishing and hunting, and mining_2015 <= 12.91
# |   |--- Arts, entertainment, and recreation, and accommodation and food services_2015 <= 27.22
# |   |   |--- class: 2
# |   |--- Arts, entertainment, and recreation, and accommodation and food services_2015 >  27.22
# |   |   |--- class: 3
# |--- Agriculture, forestry, fishing and hunting, and mining_2015 >  12.91
# |   |--- Information_2015 <= 0.54
# |   |   |--- class: 3
# |   |--- Information_2015 >  0.54
# |   |   |--- class: 4

# %%
from sklearn.metrics import classification_report

# Print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        11
#            2       0.86      0.98      0.92       121
#            3       0.00      0.00      0.00         9
#            4       0.20      0.33      0.25         3
#
#     accuracy                           0.83       144
#    macro avg       0.26      0.33      0.29       144
# weighted avg       0.72      0.83      0.77       144
# C:\Users\danan\anaconda3\envs\mlenv\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
x = data_new[['Agriculture, forestry, fishing and hunting, and mining_2019','Construction_2019','Manufacturing_2019','Wholesale trade_2019','Transportation and warehousing, and utilities_2019','Information_2019','Finance and insurance, and real estate and rental and leasing_2019', 'Arts, entertainment, and recreation, and accommodation and food services_2019','Public administration_2019']]
y = data_new['2019_Binning']

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
print(vif_data)
# Out:
#                                              feature        VIF
# 0  Agriculture, forestry, fishing and hunting, an...   1.672866
# 1                                  Construction_2019  12.335400
# 2                                 Manufacturing_2019   4.534362
# 3                               Wholesale trade_2019  12.736075
# 4  Transportation and warehousing, and utilities_...   9.370515
# 5                                   Information_2019   5.764232
# 6  Finance and insurance, and real estate and ren...  10.506623
# 7  Arts, entertainment, and recreation, and accom...  10.936844
# 8                         Public administration_2019   4.223534

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=100)

from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=2, random_state=2)
clf.fit(x_train, y_train)

#Prediction of test set
y_pred= clf.predict(x_test)

from sklearn import metrics
meanAbErr = metrics.mean_absolute_error(y_test, y_pred)
meanSqErr = metrics.mean_squared_error(y_test, y_pred)
rootMeanSqErr = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('R squared: {:.2f}'.format(clf.score(x_test,y_test)))
print('Mean Absolute Error:', meanAbErr)
print('Mean Square Error:', meanSqErr)
print('Root Mean Square Error:', rootMeanSqErr)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# R squared: 0.81
# Mean Absolute Error: 0.20833333333333334
# Mean Square Error: 0.2361111111111111
# Root Mean Square Error: 0.485912657903775
# Accuracy: 0.8055555555555556

# %%
from sklearn.tree import export_text
x1 = ['Agriculture, forestry, fishing and hunting, and mining_2019','Construction_2019','Manufacturing_2019','Wholesale trade_2019','Transportation and warehousing, and utilities_2019','Information_2019','Finance and insurance, and real estate and rental and leasing_2019', 'Arts, entertainment, and recreation, and accommodation and food services_2019','Public administration_2019']

tree_rules = export_text(clf, feature_names=x1)
print(tree_rules)
# Out:
# |--- Agriculture, forestry, fishing and hunting, and mining_2019 <= 9.71
# |   |--- Arts, entertainment, and recreation, and accommodation and food services_2019 <= 17.74
# |   |   |--- class: 2
# |   |--- Arts, entertainment, and recreation, and accommodation and food services_2019 >  17.74
# |   |   |--- class: 1
# |--- Agriculture, forestry, fishing and hunting, and mining_2019 >  9.71
# |   |--- Wholesale trade_2019 <= 3.38
# |   |   |--- class: 3
# |   |--- Wholesale trade_2019 >  3.38
# |   |   |--- class: 2

# %%
from sklearn.metrics import classification_report

# Print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        16
#            2       0.83      0.97      0.90       120
#            3       0.00      0.00      0.00         7
#            4       0.00      0.00      0.00         1
#
#     accuracy                           0.81       144
#    macro avg       0.21      0.24      0.22       144
# weighted avg       0.70      0.81      0.75       144
# C:\Users\danan\anaconda3\envs\mlenv\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
