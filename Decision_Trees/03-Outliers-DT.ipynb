# %%
# Import Dependencies
import pandas as pd
import numpy as np

# %%
# Read File(s)
data_10 = pd.read_csv("..\\Cleaned_Data\\2010_Data_Binning_Clean.csv")
data_15 = pd.read_csv("..\\Cleaned_Data\\2015_Data_Binning_Clean.csv")
data_19 = pd.read_csv("..\\Cleaned_Data\\2019_Data_Binning_Clean.csv")

# %%
data_10.head()
# Out:
#    Unnamed: 0        County_Name   State_Name  \
# 0          21        Pima County      Arizona
# 1         327  Bernalillo County   New Mexico
# 2         576      Pierce County   Washington
# 3         553   Arlington County     Virginia
# 4         580    Thurston County   Washington
#
#   Civilian employed population 16 years and over_2010  \
# 0                                            412,292
# 1                                            313,133
# 2                                            344,597
# 3                                            132,893
# 4                                            110,855
#
#   Agriculture, forestry, fishing and hunting, and mining_2010  \
# 0                                              3,711
# 1                                              2,402
# 2                                              1,805
# 3                                                128
# 4                                              2,692
#
# ...

# %%
# Remove ',' from String literals in DataFrame
data_10['Civilian employed population 16 years and over_2010'] = data_10['Civilian employed population 16 years and over_2010'].str.replace(',','')
data_10['Agriculture, forestry, fishing and hunting, and mining_2010'] = data_10['Agriculture, forestry, fishing and hunting, and mining_2010'].str.replace(',','')
data_10['Construction_2010'] = data_10['Construction_2010'].str.replace(',','')
data_10['Manufacturing_2010'] = data_10['Manufacturing_2010'].str.replace(',','')
data_10['Wholesale trade_2010'] = data_10['Wholesale trade_2010'].str.replace(',','')
data_10['Retail trade_2010'] = data_10['Retail trade_2010'].str.replace(',','')
data_10['Transportation and warehousing, and utilities_2010'] = data_10['Transportation and warehousing, and utilities_2010'].str.replace(',','')
data_10['Information_2010'] = data_10['Information_2010'].str.replace(',','')
data_10['Finance and insurance, and real estate and rental and leasing_2010'] = data_10['Finance and insurance, and real estate and rental and leasing_2010'].str.replace(',','')
data_10['Professional, scientific, and management, and administrative and waste management services_2010'] = data_10['Professional, scientific, and management, and administrative and waste management services_2010'].str.replace(',','')
data_10['Educational services, and health care and social assistance_2010'] = data_10['Educational services, and health care and social assistance_2010'].str.replace(',','')
data_10['Arts, entertainment, and recreation, and accommodation and food services_2010'] = data_10['Arts, entertainment, and recreation, and accommodation and food services_2010'].str.replace(',','')
data_10['Other services, except public administration_2010'] = data_10['Other services, except public administration_2010'].str.replace(',','')
data_10['Public administration_2010'] = data_10['Public administration_2010'].str.replace(',','')

data_15['Civilian employed population 16 years and over_2015'] = data_15['Civilian employed population 16 years and over_2015'].str.replace(',','')
data_15['Agriculture, forestry, fishing and hunting, and mining_2015'] = data_15['Agriculture, forestry, fishing and hunting, and mining_2015'].str.replace(',','')
data_15['Construction_2015'] = data_15['Construction_2015'].str.replace(',','')
data_15['Manufacturing_2015'] = data_15['Manufacturing_2015'].str.replace(',','')
data_15['Wholesale trade_2015'] = data_15['Wholesale trade_2015'].str.replace(',','')
data_15['Retail trade_2015'] = data_15['Retail trade_2015'].str.replace(',','')
data_15['Transportation and warehousing, and utilities_2015'] = data_15['Transportation and warehousing, and utilities_2015'].str.replace(',','')
data_15['Information_2015'] = data_15['Information_2015'].str.replace(',','')
data_15['Finance and insurance, and real estate and rental and leasing_2015'] = data_15['Finance and insurance, and real estate and rental and leasing_2015'].str.replace(',','')
data_15['Professional, scientific, and management, and administrative and waste management services_2015'] = data_15['Professional, scientific, and management, and administrative and waste management services_2015'].str.replace(',','')
data_15['Educational services, and health care and social assistance_2015'] = data_15['Educational services, and health care and social assistance_2015'].str.replace(',','')
data_15['Arts, entertainment, and recreation, and accommodation and food services_2015'] = data_15['Arts, entertainment, and recreation, and accommodation and food services_2015'].str.replace(',','')
data_15['Other services, except public administration_2015'] = data_15['Other services, except public administration_2015'].str.replace(',','')
data_15['Public administration_2015'] = data_15['Public administration_2015'].str.replace(',','')

data_19['Civilian employed population 16 years and over_2019'] = data_19['Civilian employed population 16 years and over_2019'].str.replace(',','')
data_19['Agriculture, forestry, fishing and hunting, and mining_2019'] =  data_19['Agriculture, forestry, fishing and hunting, and mining_2019'].str.replace(',','')
data_19['Construction_2019'] =  data_19['Construction_2019'].str.replace(',','')
data_19['Manufacturing_2019'] =  data_19['Manufacturing_2019'].str.replace(',','')
data_19['Wholesale trade_2019'] =  data_19['Wholesale trade_2019'].str.replace(',','')
data_19['Retail trade_2019'] = data_19['Retail trade_2019'].str.replace(',','')
data_19['Transportation and warehousing, and utilities_2019'] =  data_19['Transportation and warehousing, and utilities_2019'].str.replace(',','')
data_19['Information_2019'] =  data_19['Information_2019'].str.replace(',','')
data_19['Finance and insurance, and real estate and rental and leasing_2019'] =  data_19['Finance and insurance, and real estate and rental and leasing_2019'].str.replace(',','')
data_19['Professional, scientific, and management, and administrative and waste management services_2019'] =  data_19['Professional, scientific, and management, and administrative and waste management services_2019'].str.replace(',','')
data_19['Educational services, and health care and social assistance_2019'] =  data_19['Educational services, and health care and social assistance_2019'].str.replace(',','')
data_19['Arts, entertainment, and recreation, and accommodation and food services_2019'] =  data_19['Arts, entertainment, and recreation, and accommodation and food services_2019'].str.replace(',','')
data_19['Other services, except public administration_2019'] =  data_19['Other services, except public administration_2019'].str.replace(',','')
data_19['Public administration_2019'] =  data_19['Public administration_2019'].str.replace(',','')

# %%
# Remove industry_2010 column
del data_10['Industry_2010']
del data_10['County_Name']
del data_10['State_Name']

del data_15['County_Name']
del data_15['State_Name']

del data_19['County_Name']
del data_19['State_Name']

# %%
data_10.head()
# Out:
#    Unnamed: 0 Civilian employed population 16 years and over_2010  \
# 0          21                                             412292
# 1         327                                             313133
# 2         576                                             344597
# 3         553                                             132893
# 4         580                                             110855
#
#   Agriculture, forestry, fishing and hunting, and mining_2010  \
# 0                                               3711
# 1                                               2402
# 2                                               1805
# 3                                                128
# 4                                               2692
#
#   Construction_2010 Manufacturing_2010 Wholesale trade_2010 Retail trade_2010  \
# 0             23958              29763                 5998             51249
# 1             22197              14327                 7556             38113
# ...

# %%
# Convert values in data to integer type for ML
data_10new = data_10.copy()
data_10new = data_10new.astype(int)

data_15new = data_15.copy()
data_15new = data_15new.astype(int)

data_19new = data_19.copy()
data_19new = data_19new.astype(int)

# %%
# Convert values in data_2010 to proportion of total employed
data_10new['Agriculture, forestry, fishing and hunting, and mining_2010'] = (data_10new['Agriculture, forestry, fishing and hunting, and mining_2010']/data_10new['Civilian employed population 16 years and over_2010'])*100
data_10new['Construction_2010'] = (data_10new['Construction_2010']/data_10new['Civilian employed population 16 years and over_2010'])*100
data_10new['Manufacturing_2010'] = (data_10new['Manufacturing_2010']/data_10new['Civilian employed population 16 years and over_2010'])*100
data_10new['Wholesale trade_2010'] = (data_10new['Wholesale trade_2010']/data_10new['Civilian employed population 16 years and over_2010'])*100
data_10new['Retail trade_2010'] = (data_10new['Retail trade_2010']/data_10new['Civilian employed population 16 years and over_2010'])*100
data_10new['Transportation and warehousing, and utilities_2010'] = (data_10new['Transportation and warehousing, and utilities_2010']/data_10new['Civilian employed population 16 years and over_2010'])*100
data_10new['Information_2010'] = (data_10new['Information_2010']/data_10new['Civilian employed population 16 years and over_2010'])*100
data_10new['Finance and insurance, and real estate and rental and leasing_2010'] = (data_10new['Finance and insurance, and real estate and rental and leasing_2010']/data_10new['Civilian employed population 16 years and over_2010'])*100
data_10new['Professional, scientific, and management, and administrative and waste management services_2010'] = (data_10new['Professional, scientific, and management, and administrative and waste management services_2010']/data_10new['Civilian employed population 16 years and over_2010'])*100
data_10new['Educational services, and health care and social assistance_2010'] = (data_10new['Educational services, and health care and social assistance_2010']/data_10new['Civilian employed population 16 years and over_2010'])*100
data_10new['Arts, entertainment, and recreation, and accommodation and food services_2010'] = (data_10new['Arts, entertainment, and recreation, and accommodation and food services_2010']/data_10new['Civilian employed population 16 years and over_2010'])*100
data_10new['Other services, except public administration_2010'] = (data_10new['Other services, except public administration_2010']/data_10new['Civilian employed population 16 years and over_2010'])*100
data_10new['Public administration_2010'] = (data_10new['Public administration_2010']/data_10new['Civilian employed population 16 years and over_2010'])*100

# Convert values in data_2015 to proportion of total employed
data_15new['Agriculture, forestry, fishing and hunting, and mining_2015'] = (data_15new['Agriculture, forestry, fishing and hunting, and mining_2015']/data_15new['Civilian employed population 16 years and over_2015'])*100
data_15new['Construction_2015'] = (data_15new['Construction_2015']/data_15new['Civilian employed population 16 years and over_2015'])*100
data_15new['Manufacturing_2015'] = (data_15new['Manufacturing_2015']/data_15new['Civilian employed population 16 years and over_2015'])*100
data_15new['Wholesale trade_2015'] = (data_15new['Wholesale trade_2015']/data_15new['Civilian employed population 16 years and over_2015'])*100
data_15new['Retail trade_2015'] = (data_15new['Retail trade_2015']/data_15new['Civilian employed population 16 years and over_2015'])*100
data_15new['Transportation and warehousing, and utilities_2015'] = (data_15new['Transportation and warehousing, and utilities_2015']/data_15new['Civilian employed population 16 years and over_2015'])*100
data_15new['Information_2015'] = (data_15new['Information_2015']/data_15new['Civilian employed population 16 years and over_2015'])*100
data_15new['Finance and insurance, and real estate and rental and leasing_2015'] = (data_15new['Finance and insurance, and real estate and rental and leasing_2015']/data_15new['Civilian employed population 16 years and over_2015'])*100
data_15new['Professional, scientific, and management, and administrative and waste management services_2015'] = (data_15new['Professional, scientific, and management, and administrative and waste management services_2015']/data_15new['Civilian employed population 16 years and over_2015'])*100
data_15new['Educational services, and health care and social assistance_2015'] = (data_15new['Educational services, and health care and social assistance_2015']/data_15new['Civilian employed population 16 years and over_2015'])*100
data_15new['Arts, entertainment, and recreation, and accommodation and food services_2015'] = (data_15new['Arts, entertainment, and recreation, and accommodation and food services_2015']/data_15new['Civilian employed population 16 years and over_2015'])*100
data_15new['Other services, except public administration_2015'] = (data_15new['Other services, except public administration_2015']/data_15new['Civilian employed population 16 years and over_2015'])*100
data_15new['Public administration_2015'] = (data_15new['Public administration_2015']/data_15new['Civilian employed population 16 years and over_2015'])*100

# Convert values in data_2019 to proportion of total employed
data_19new['Agriculture, forestry, fishing and hunting, and mining_2019'] = (data_19new['Agriculture, forestry, fishing and hunting, and mining_2019']/data_19new['Civilian employed population 16 years and over_2019'])*100
data_19new['Construction_2019'] = (data_19new['Construction_2019']/data_19new['Civilian employed population 16 years and over_2019'])*100
data_19new['Manufacturing_2019'] = (data_19new['Manufacturing_2019']/data_19new['Civilian employed population 16 years and over_2019'])*100
data_19new['Wholesale trade_2019'] = (data_19new['Wholesale trade_2019']/data_19new['Civilian employed population 16 years and over_2019'])*100
data_19new['Retail trade_2019'] = (data_19new['Retail trade_2019']/data_19new['Civilian employed population 16 years and over_2019'])*100
data_19new['Transportation and warehousing, and utilities_2019'] = (data_19new['Transportation and warehousing, and utilities_2019']/data_19new['Civilian employed population 16 years and over_2019'])*100
data_19new['Information_2019'] = (data_19new['Information_2019']/data_19new['Civilian employed population 16 years and over_2019'])*100
data_19new['Finance and insurance, and real estate and rental and leasing_2019'] = (data_19new['Finance and insurance, and real estate and rental and leasing_2019']/data_19new['Civilian employed population 16 years and over_2019'])*100
data_19new['Professional, scientific, and management, and administrative and waste management services_2019'] = (data_19new['Professional, scientific, and management, and administrative and waste management services_2019']/data_19new['Civilian employed population 16 years and over_2019'])*100
data_19new['Educational services, and health care and social assistance_2019'] = (data_19new['Educational services, and health care and social assistance_2019']/data_19new['Civilian employed population 16 years and over_2019'])*100
data_19new['Arts, entertainment, and recreation, and accommodation and food services_2019'] = (data_19new['Arts, entertainment, and recreation, and accommodation and food services_2019']/data_19new['Civilian employed population 16 years and over_2019'])*100
data_19new['Other services, except public administration_2019'] = (data_19new['Other services, except public administration_2019']/data_19new['Civilian employed population 16 years and over_2019'])*100
data_19new['Public administration_2019'] = (data_19new['Public administration_2019']/data_19new['Civilian employed population 16 years and over_2019'])*100

# %%
# Set variables for 2010 data 
x = data_10new[['Agriculture, forestry, fishing and hunting, and mining_2010','Construction_2010','Manufacturing_2010','Wholesale trade_2010','Retail trade_2010', 'Transportation and warehousing, and utilities_2010','Information_2010','Finance and insurance, and real estate and rental and leasing_2010', 'Professional, scientific, and management, and administrative and waste management services_2010','Educational services, and health care and social assistance_2010','Arts, entertainment, and recreation, and accommodation and food services_2010','Other services, except public administration_2010','Public administration_2010']]
y = data_10new['2010_Binning']

# Use VIF to review collinearity of variables
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
print(vif_data)
# Out:
#                                               feature        VIF
# 0   Agriculture, forestry, fishing and hunting, an...   2.466427
# 1                                   Construction_2010  20.195479
# 2                                  Manufacturing_2010   6.606385
# 3                                Wholesale trade_2010  13.466240
# 4                                   Retail trade_2010  46.461460
# 5   Transportation and warehousing, and utilities_...  11.478730
# 6                                    Information_2010  10.117229
# 7   Finance and insurance, and real estate and ren...  11.658433
# 8   Professional, scientific, and management, and ...  19.804772
# 9   Educational services, and health care and soci...  24.405291
# 10  Arts, entertainment, and recreation, and accom...  13.446795
# 11  Other services, except public administration_2010  28.905300
# 12                         Public administration_2010   5.398255

# %%
# Split dataset into training and testing sets
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=100)

# Create and fit DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=3, random_state=2)
clf.fit(x_train, y_train)

#Prediction of test set
y_pred= clf.predict(x_test)

from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# R squared: 0.78
# Mean Absolute Error: 0.2222222222222222
# Mean Square Error: 0.2222222222222222
# Root Mean Square Error: 0.4714045207910317
# Accuracy: 0.7777777777777778

# %%
# Create visual for Decision Tree
from sklearn.tree import export_text
x1 = ['Agriculture, forestry, fishing and hunting, and mining_2010','Construction_2010','Manufacturing_2010','Wholesale trade_2010','Retail trade_2010', 'Transportation and warehousing, and utilities_2010','Information_2010','Finance and insurance, and real estate and rental and leasing_2010', 'Professional, scientific, and management, and administrative and waste management services_2010','Educational services, and health care and social assistance_2010','Arts, entertainment, and recreation, and accommodation and food services_2010','Other services, except public administration_2010','Public administration_2010']

tree_rules = export_text(clf, feature_names=x1)
print(tree_rules)
# Out:
# |--- Construction_2010 <= 10.54
# |   |--- Professional, scientific, and management, and administrative and waste management services_2010 <= 11.96
# |   |   |--- Public administration_2010 <= 14.11
# |   |   |   |--- class: 2
# |   |   |--- Public administration_2010 >  14.11
# |   |   |   |--- class: 1
# |   |--- Professional, scientific, and management, and administrative and waste management services_2010 >  11.96
# |   |   |--- Finance and insurance, and real estate and rental and leasing_2010 <= 4.37
# |   |   |   |--- class: 1
# |   |   |--- Finance and insurance, and real estate and rental and leasing_2010 >  4.37
# |   |   |   |--- class: 2
# |--- Construction_2010 >  10.54
# |   |--- Construction_2010 <= 10.94
# |   |   |--- class: 1
# |   |--- Construction_2010 >  10.94
# |   |   |--- class: 2

# %%
# Print the classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         5
#            2       0.80      0.97      0.88        94
#            3       0.00      0.00      0.00        18
#
#     accuracy                           0.78       117
#    macro avg       0.27      0.32      0.29       117
# weighted avg       0.64      0.78      0.70       117
# C:\Users\danan\anaconda3\envs\mlenv\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\danan\anaconda3\envs\mlenv\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
# Set variables for 2015 data
x = data_15new[['Agriculture, forestry, fishing and hunting, and mining_2015','Construction_2015','Manufacturing_2015','Wholesale trade_2015','Retail trade_2015', 'Transportation and warehousing, and utilities_2015','Information_2015','Finance and insurance, and real estate and rental and leasing_2015', 'Professional, scientific, and management, and administrative and waste management services_2015','Educational services, and health care and social assistance_2015','Arts, entertainment, and recreation, and accommodation and food services_2015','Other services, except public administration_2015','Public administration_2015']]
y = data_15new['2015_Binning']

# Use VIF to review collinearity of variables
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
print(vif_data)
# Out:
#                                               feature        VIF
# 0   Agriculture, forestry, fishing and hunting, an...   2.528007
# 1                                   Construction_2015  16.794984
# 2                                  Manufacturing_2015   5.644869
# 3                                Wholesale trade_2015  12.608150
# 4                                   Retail trade_2015  46.794999
# 5   Transportation and warehousing, and utilities_...  10.267041
# 6                                    Information_2015  11.548953
# 7   Finance and insurance, and real estate and ren...  11.700146
# 8   Professional, scientific, and management, and ...  22.517424
# 9   Educational services, and health care and soci...  23.072794
# 10  Arts, entertainment, and recreation, and accom...  15.973924
# 11  Other services, except public administration_2015  28.095075
# 12                         Public administration_2015   5.351283

# %%
# Split dataset into training and testing sets
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=100)

# Create and fit DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=4, random_state=2)
clf.fit(x_train, y_train)

#Prediction of test set
y_pred= clf.predict(x_test)

from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# R squared: 0.86
# Mean Absolute Error: 0.1415929203539823
# Mean Square Error: 0.1415929203539823
# Root Mean Square Error: 0.3762883473534389
# Accuracy: 0.8584070796460177

# %%
# Create visual for Decision Tree
rom sklearn.tree import export_text
x1 = ['Agriculture, forestry, fishing and hunting, and mining_2015','Construction_2015','Manufacturing_2015','Wholesale trade_2015','Retail trade_2015', 'Transportation and warehousing, and utilities_2015','Information_2015','Finance and insurance, and real estate and rental and leasing_2015', 'Professional, scientific, and management, and administrative and waste management services_2015','Educational services, and health care and social assistance_2015','Arts, entertainment, and recreation, and accommodation and food services_2015','Other services, except public administration_2015','Public administration_2015']

tree_rules = export_text(clf, feature_names=x1)
print(tree_rules)
# Out:
# |--- Agriculture, forestry, fishing and hunting, and mining_2015 <= 4.50
# |   |--- Arts, entertainment, and recreation, and accommodation and food services_2015 <= 20.55
# |   |   |--- Construction_2015 <= 8.24
# |   |   |   |--- class: 2
# |   |   |--- Construction_2015 >  8.24
# |   |   |   |--- class: 2
# |   |--- Arts, entertainment, and recreation, and accommodation and food services_2015 >  20.55
# |   |   |--- class: 1
# |--- Agriculture, forestry, fishing and hunting, and mining_2015 >  4.50
# |   |--- Wholesale trade_2015 <= 2.16
# |   |   |--- Educational services, and health care and social assistance_2015 <= 27.04
# |   |   |   |--- class: 1
# |   |   |--- Educational services, and health care and social assistance_2015 >  27.04
# |   |   |   |--- class: 3
# |   |--- Wholesale trade_2015 >  2.16
# |   |   |--- class: 2

# %%
# Print the classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         9
#            2       0.89      0.96      0.92       101
#            3       0.00      0.00      0.00         3
#
#     accuracy                           0.86       113
#    macro avg       0.30      0.32      0.31       113
# weighted avg       0.80      0.86      0.83       113

# %%
# Set variables for 2019 data
x = data_19new[['Agriculture, forestry, fishing and hunting, and mining_2019','Construction_2019','Manufacturing_2019','Wholesale trade_2019','Retail trade_2019', 'Transportation and warehousing, and utilities_2019','Information_2019','Finance and insurance, and real estate and rental and leasing_2019', 'Professional, scientific, and management, and administrative and waste management services_2019','Educational services, and health care and social assistance_2019','Arts, entertainment, and recreation, and accommodation and food services_2019','Other services, except public administration_2019','Public administration_2019']]
y = data_19new['2019_Binning']

# Use VIF to review collinearity of variables
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
print(vif_data)
# Out:
#                                               feature        VIF
# 0   Agriculture, forestry, fishing and hunting, an...   2.529909
# 1                                   Construction_2019  16.810886
# 2                                  Manufacturing_2019   5.727907
# 3                                Wholesale trade_2019  12.375353
# 4                                   Retail trade_2019  45.337870
# 5   Transportation and warehousing, and utilities_...   9.764367
# 6                                    Information_2019  10.219847
# 7   Finance and insurance, and real estate and ren...  11.935967
# 8   Professional, scientific, and management, and ...  19.057235
# 9   Educational services, and health care and soci...  23.835836
# 10  Arts, entertainment, and recreation, and accom...  15.399581
# 11  Other services, except public administration_2019  23.265631
# 12                         Public administration_2019   5.630051

# %%
# Split dataset into training and testing sets
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=100)

# Create and fit DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=3, random_state=2)
clf.fit(x_train, y_train)

#Prediction of test set
y_pred= clf.predict(x_test)

from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# R squared: 0.90
# Mean Absolute Error: 0.09649122807017543
# Mean Square Error: 0.09649122807017543
# Root Mean Square Error: 0.31063037209869776
# Accuracy: 0.9035087719298246

# %%
# Create visual for Decision Tree
from sklearn.tree import export_text
x1 = ['Agriculture, forestry, fishing and hunting, and mining_2019','Construction_2019','Manufacturing_2019','Wholesale trade_2019','Retail trade_2019', 'Transportation and warehousing, and utilities_2019','Information_2019','Finance and insurance, and real estate and rental and leasing_2019', 'Professional, scientific, and management, and administrative and waste management services_2019','Educational services, and health care and social assistance_2019','Arts, entertainment, and recreation, and accommodation and food services_2019','Other services, except public administration_2019','Public administration_2019']
tree_rules = export_text(clf, feature_names=x1)
print(tree_rules)
# Out:
# |--- Agriculture, forestry, fishing and hunting, and mining_2019 <= 1.30
# |   |--- Arts, entertainment, and recreation, and accommodation and food services_2019 <= 23.67
# |   |   |--- Wholesale trade_2019 <= 0.99
# |   |   |   |--- class: 1
# |   |   |--- Wholesale trade_2019 >  0.99
# |   |   |   |--- class: 2
# |   |--- Arts, entertainment, and recreation, and accommodation and food services_2019 >  23.67
# |   |   |--- class: 1
# |--- Agriculture, forestry, fishing and hunting, and mining_2019 >  1.30
# |   |--- Retail trade_2019 <= 12.70
# |   |   |--- Agriculture, forestry, fishing and hunting, and mining_2019 <= 1.34
# |   |   |   |--- class: 1
# |   |   |--- Agriculture, forestry, fishing and hunting, and mining_2019 >  1.34
# |   |   |   |--- class: 2
# |   |--- Retail trade_2019 >  12.70
# |   |   |--- Construction_2019 <= 8.00
# |   |   |   |--- class: 2
# |   |   |--- Construction_2019 >  8.00
# |   |   |   |--- class: 1

# %%
# Print the classification report 
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.20      0.20      0.20         5
#            2       0.94      0.96      0.95       106
#            3       0.00      0.00      0.00         3
#
#     accuracy                           0.90       114
#    macro avg       0.38      0.39      0.38       114
# weighted avg       0.88      0.90      0.89       114
# C:\Users\danan\anaconda3\envs\mlenv\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\danan\anaconda3\envs\mlenv\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
