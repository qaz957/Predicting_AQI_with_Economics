# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("..\\Cleaned_Data\\AllYears_Data_Binning.csv")

# %%
data.head()
# Out:
#    Unnamed: 0       County_Name State_Name  \
# 0           0    Baldwin County    Alabama
# 1           4    Houston County    Alabama
# 2           5  Jefferson County    Alabama
# 3           7    Madison County    Alabama
# 4           8     Mobile County    Alabama
#
#   Civilian employed population 16 years and over_2010  \
# 0                                             77,263
# 1                                             45,470
# 2                                            289,454
# 3                                            156,411
# 4                                            170,552
#
#   Agriculture, forestry, fishing and hunting, and mining_2010  \
# 0                                              1,302
# 1                                                790
# 2                                              1,761
# 3                                                569
# 4                                              2,025
#
# ...

# %%
# Remove ',' from String literals in DataFrame
data['Civilian employed population 16 years and over_2010'] = data['Civilian employed population 16 years and over_2010'].str.replace(',','')
data['Agriculture, forestry, fishing and hunting, and mining_2010'] = data['Agriculture, forestry, fishing and hunting, and mining_2010'].str.replace(',','')
data['Construction_2010'] = data['Construction_2010'].str.replace(',','')
data['Manufacturing_2010'] = data['Manufacturing_2010'].str.replace(',','')
data['Wholesale trade_2010'] = data['Wholesale trade_2010'].str.replace(',','')
data['Retail trade_2010'] = data['Retail trade_2010'].str.replace(',','')
data['Transportation and warehousing, and utilities_2010'] = data['Transportation and warehousing, and utilities_2010'].str.replace(',','')
data['Information_2010'] = data['Information_2010'].str.replace(',','')
data['Finance and insurance, and real estate and rental and leasing_2010'] = data['Finance and insurance, and real estate and rental and leasing_2010'].str.replace(',','')
data['Professional, scientific, and management, and administrative and waste management services_2010'] = data['Professional, scientific, and management, and administrative and waste management services_2010'].str.replace(',','')
data['Educational services, and health care and social assistance_2010'] = data['Educational services, and health care and social assistance_2010'].str.replace(',','')
data['Arts, entertainment, and recreation, and accommodation and food services_2010'] = data['Arts, entertainment, and recreation, and accommodation and food services_2010'].str.replace(',','')
data['Other services, except public administration_2010'] = data['Other services, except public administration_2010'].str.replace(',','')
data['Public administration_2010'] = data['Public administration_2010'].str.replace(',','')

data['Civilian employed population 16 years and over_2015'] = data['Civilian employed population 16 years and over_2015'].str.replace(',','')
data['Agriculture, forestry, fishing and hunting, and mining_2015'] = data['Agriculture, forestry, fishing and hunting, and mining_2015'].str.replace(',','')
data['Construction_2015'] = data['Construction_2015'].str.replace(',','')
data['Manufacturing_2015'] = data['Manufacturing_2015'].str.replace(',','')
data['Wholesale trade_2015'] = data['Wholesale trade_2015'].str.replace(',','')
data['Retail trade_2015'] = data['Retail trade_2015'].str.replace(',','')
data['Transportation and warehousing, and utilities_2015'] = data['Transportation and warehousing, and utilities_2015'].str.replace(',','')
data['Information_2015'] = data['Information_2015'].str.replace(',','')
data['Finance and insurance, and real estate and rental and leasing_2015'] = data['Finance and insurance, and real estate and rental and leasing_2015'].str.replace(',','')
data['Professional, scientific, and management, and administrative and waste management services_2015'] = data['Professional, scientific, and management, and administrative and waste management services_2015'].str.replace(',','')
data['Educational services, and health care and social assistance_2015'] = data['Educational services, and health care and social assistance_2015'].str.replace(',','')
data['Arts, entertainment, and recreation, and accommodation and food services_2015'] = data['Arts, entertainment, and recreation, and accommodation and food services_2015'].str.replace(',','')
data['Other services, except public administration_2015'] = data['Other services, except public administration_2015'].str.replace(',','')
data['Public administration_2015'] = data['Public administration_2015'].str.replace(',','')

data['Civilian employed population 16 years and over_2019'] = data['Civilian employed population 16 years and over_2019'].str.replace(',','')
data['Agriculture, forestry, fishing and hunting, and mining_2019'] = data['Agriculture, forestry, fishing and hunting, and mining_2019'].str.replace(',','')
data['Construction_2019'] = data['Construction_2019'].str.replace(',','')
data['Manufacturing_2019'] = data['Manufacturing_2019'].str.replace(',','')
data['Wholesale trade_2019'] = data['Wholesale trade_2019'].str.replace(',','')
data['Retail trade_2019'] = data['Retail trade_2019'].str.replace(',','')
data['Transportation and warehousing, and utilities_2019'] = data['Transportation and warehousing, and utilities_2019'].str.replace(',','')
data['Information_2019'] = data['Information_2019'].str.replace(',','')
data['Finance and insurance, and real estate and rental and leasing_2019'] = data['Finance and insurance, and real estate and rental and leasing_2019'].str.replace(',','')
data['Professional, scientific, and management, and administrative and waste management services_2019'] = data['Professional, scientific, and management, and administrative and waste management services_2019'].str.replace(',','')
data['Educational services, and health care and social assistance_2019'] = data['Educational services, and health care and social assistance_2019'].str.replace(',','')
data['Arts, entertainment, and recreation, and accommodation and food services_2019'] = data['Arts, entertainment, and recreation, and accommodation and food services_2019'].str.replace(',','')
data['Other services, except public administration_2019'] = data['Other services, except public administration_2019'].str.replace(',','')
data['Public administration_2019'] = data['Public administration_2019'].str.replace(',','')

# %%
# Remove industry_2010 column
del data['Industry_2010']
del data['Industry_2015']
del data['Industry_2019']
del data['County_Name']
del data['State_Name']

# %%
data.head()
# Out:
#    Unnamed: 0 Civilian employed population 16 years and over_2010  \
# 0           0                                              77263
# 1           4                                              45470
# 2           5                                             289454
# 3           7                                             156411
# 4           8                                             170552
#
#   Agriculture, forestry, fishing and hunting, and mining_2010  \
# 0                                               1302
# 1                                                790
# 2                                               1761
# 3                                                569
# 4                                               2025
#
#   Construction_2010 Manufacturing_2010 Wholesale trade_2010 Retail trade_2010  \
# 0              6489               6134                 2131              9525
# 1              2967               4237                 1897              6225
# ...

# %%
# Convert values in data_2010 to integer type for Regression
data_new = data.copy()
data_new = data_new.astype(int)

# %%
# Convert values in data_2010 to proportion of total employed
data_new['Agriculture, forestry, fishing and hunting, and mining_2010'] = (data_new['Agriculture, forestry, fishing and hunting, and mining_2010']/data_new['Civilian employed population 16 years and over_2010'])*100
data_new['Construction_2010'] = (data_new['Construction_2010']/data_new['Civilian employed population 16 years and over_2010'])*100
data_new['Manufacturing_2010'] = (data_new['Manufacturing_2010']/data_new['Civilian employed population 16 years and over_2010'])*100
data_new['Wholesale trade_2010'] = (data_new['Wholesale trade_2010']/data_new['Civilian employed population 16 years and over_2010'])*100
data_new['Retail trade_2010'] = (data_new['Retail trade_2010']/data_new['Civilian employed population 16 years and over_2010'])*100
data_new['Transportation and warehousing, and utilities_2010'] = (data_new['Transportation and warehousing, and utilities_2010']/data_new['Civilian employed population 16 years and over_2010'])*100
data_new['Information_2010'] = (data_new['Information_2010']/data_new['Civilian employed population 16 years and over_2010'])*100
data_new['Finance and insurance, and real estate and rental and leasing_2010'] = (data_new['Finance and insurance, and real estate and rental and leasing_2010']/data_new['Civilian employed population 16 years and over_2010'])*100
data_new['Professional, scientific, and management, and administrative and waste management services_2010'] = (data_new['Professional, scientific, and management, and administrative and waste management services_2010']/data_new['Civilian employed population 16 years and over_2010'])*100
data_new['Educational services, and health care and social assistance_2010'] = (data_new['Educational services, and health care and social assistance_2010']/data_new['Civilian employed population 16 years and over_2010'])*100
data_new['Arts, entertainment, and recreation, and accommodation and food services_2010'] = (data_new['Arts, entertainment, and recreation, and accommodation and food services_2010']/data_new['Civilian employed population 16 years and over_2010'])*100
data_new['Other services, except public administration_2010'] = (data_new['Other services, except public administration_2010']/data_new['Civilian employed population 16 years and over_2010'])*100
data_new['Public administration_2010'] = (data_new['Public administration_2010']/data_new['Civilian employed population 16 years and over_2010'])*100

# Convert values in data_2015 to proportion of total employed
data_new['Agriculture, forestry, fishing and hunting, and mining_2015'] = (data_new['Agriculture, forestry, fishing and hunting, and mining_2015']/data_new['Civilian employed population 16 years and over_2015'])*100
data_new['Construction_2015'] = (data_new['Construction_2015']/data_new['Civilian employed population 16 years and over_2015'])*100
data_new['Manufacturing_2015'] = (data_new['Manufacturing_2015']/data_new['Civilian employed population 16 years and over_2015'])*100
data_new['Wholesale trade_2015'] = (data_new['Wholesale trade_2015']/data_new['Civilian employed population 16 years and over_2015'])*100
data_new['Retail trade_2015'] = (data_new['Retail trade_2015']/data_new['Civilian employed population 16 years and over_2015'])*100
data_new['Transportation and warehousing, and utilities_2015'] = (data_new['Transportation and warehousing, and utilities_2015']/data_new['Civilian employed population 16 years and over_2015'])*100
data_new['Information_2015'] = (data_new['Information_2015']/data_new['Civilian employed population 16 years and over_2015'])*100
data_new['Finance and insurance, and real estate and rental and leasing_2015'] = (data_new['Finance and insurance, and real estate and rental and leasing_2015']/data_new['Civilian employed population 16 years and over_2015'])*100
data_new['Professional, scientific, and management, and administrative and waste management services_2015'] = (data_new['Professional, scientific, and management, and administrative and waste management services_2015']/data_new['Civilian employed population 16 years and over_2015'])*100
data_new['Educational services, and health care and social assistance_2015'] = (data_new['Educational services, and health care and social assistance_2015']/data_new['Civilian employed population 16 years and over_2015'])*100
data_new['Arts, entertainment, and recreation, and accommodation and food services_2015'] = (data_new['Arts, entertainment, and recreation, and accommodation and food services_2015']/data_new['Civilian employed population 16 years and over_2015'])*100
data_new['Other services, except public administration_2015'] = (data_new['Other services, except public administration_2015']/data_new['Civilian employed population 16 years and over_2015'])*100
data_new['Public administration_2015'] = (data_new['Public administration_2015']/data_new['Civilian employed population 16 years and over_2015'])*100

# Convert values in data_2019 to proportion of total employed
data_new['Agriculture, forestry, fishing and hunting, and mining_2019'] = (data_new['Agriculture, forestry, fishing and hunting, and mining_2019']/data_new['Civilian employed population 16 years and over_2019'])*100
data_new['Construction_2019'] = (data_new['Construction_2019']/data_new['Civilian employed population 16 years and over_2019'])*100
data_new['Manufacturing_2019'] = (data_new['Manufacturing_2019']/data_new['Civilian employed population 16 years and over_2019'])*100
data_new['Wholesale trade_2019'] = (data_new['Wholesale trade_2019']/data_new['Civilian employed population 16 years and over_2019'])*100
data_new['Retail trade_2019'] = (data_new['Retail trade_2019']/data_new['Civilian employed population 16 years and over_2019'])*100
data_new['Transportation and warehousing, and utilities_2019'] = (data_new['Transportation and warehousing, and utilities_2019']/data_new['Civilian employed population 16 years and over_2019'])*100
data_new['Information_2019'] = (data_new['Information_2019']/data_new['Civilian employed population 16 years and over_2019'])*100
data_new['Finance and insurance, and real estate and rental and leasing_2019'] = (data_new['Finance and insurance, and real estate and rental and leasing_2019']/data_new['Civilian employed population 16 years and over_2019'])*100
data_new['Professional, scientific, and management, and administrative and waste management services_2019'] = (data_new['Professional, scientific, and management, and administrative and waste management services_2019']/data_new['Civilian employed population 16 years and over_2019'])*100
data_new['Educational services, and health care and social assistance_2019'] = (data_new['Educational services, and health care and social assistance_2019']/data_new['Civilian employed population 16 years and over_2019'])*100
data_new['Arts, entertainment, and recreation, and accommodation and food services_2019'] = (data_new['Arts, entertainment, and recreation, and accommodation and food services_2019']/data_new['Civilian employed population 16 years and over_2019'])*100
data_new['Other services, except public administration_2019'] = (data_new['Other services, except public administration_2019']/data_new['Civilian employed population 16 years and over_2019'])*100
data_new['Public administration_2019'] = (data_new['Public administration_2019']/data_new['Civilian employed population 16 years and over_2019'])*100

# %%
data_new.columns
# Out:
# Index(['Unnamed: 0', 'Civilian employed population 16 years and over_2010',
#        'Agriculture, forestry, fishing and hunting, and mining_2010',
#        'Construction_2010', 'Manufacturing_2010', 'Wholesale trade_2010',
#        'Retail trade_2010',
#        'Transportation and warehousing, and utilities_2010',
#        'Information_2010',
#        'Finance and insurance, and real estate and rental and leasing_2010',
#        'Professional, scientific, and management, and administrative and waste management services_2010',
#        'Educational services, and health care and social assistance_2010',
#        'Arts, entertainment, and recreation, and accommodation and food services_2010',
#        'Other services, except public administration_2010',
#        'Public administration_2010',
#        'Civilian employed population 16 years and over_2015',
#        'Agriculture, forestry, fishing and hunting, and mining_2015',
# ...

# %%
x = data_new[['Agriculture, forestry, fishing and hunting, and mining_2010','Construction_2010','Manufacturing_2010','Wholesale trade_2010','Retail trade_2010', 'Transportation and warehousing, and utilities_2010','Information_2010','Finance and insurance, and real estate and rental and leasing_2010', 'Professional, scientific, and management, and administrative and waste management services_2010','Educational services, and health care and social assistance_2010','Arts, entertainment, and recreation, and accommodation and food services_2010','Other services, except public administration_2010','Public administration_2010']]
y = data_new['2010_Binning']

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
print(vif_data)
# Out:
#                                               feature        VIF
# 0   Agriculture, forestry, fishing and hunting, an...   1.785733
# 1                                   Construction_2010  19.059585
# 2                                  Manufacturing_2010   6.483578
# 3                                Wholesale trade_2010  13.618890
# 4                                   Retail trade_2010  49.975024
# 5   Transportation and warehousing, and utilities_...  11.675501
# 6                                    Information_2010  11.409443
# 7   Finance and insurance, and real estate and ren...  11.752594
# 8   Professional, scientific, and management, and ...  20.148029
# 9   Educational services, and health care and soci...  24.564686
# 10  Arts, entertainment, and recreation, and accom...  13.264993
# 11  Other services, except public administration_2010  30.438917
# 12                         Public administration_2010   5.445901

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=100)

from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=2, random_state=2)
clf.fit(x_train, y_train)

#Prediction of test set
y_pred= clf.predict(x_test)

# import export_graphviz
from sklearn.tree import export_graphviz 
  
# export the decision tree to a tree.dot file
# for visualizing the plot easily anywhere
graph = export_graphviz(clf, out_file ='tree2010.dot') 

from sklearn import metrics
meanAbErr = metrics.mean_absolute_error(y_test, y_pred)
meanSqErr = metrics.mean_squared_error(y_test, y_pred)
rootMeanSqErr = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('R squared: {:.2f}'.format(clf.score(x_test,y_test)))
print('Mean Absolute Error:', meanAbErr)
print('Mean Square Error:', meanSqErr)
print('Root Mean Square Error:', rootMeanSqErr)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# R squared: 0.76
# Mean Absolute Error: 0.25
# Mean Square Error: 0.2638888888888889
# Root Mean Square Error: 0.5137011669140814
# Accuracy: 0.7569444444444444

# %%
x = data_new[['Agriculture, forestry, fishing and hunting, and mining_2015','Construction_2015','Manufacturing_2015','Wholesale trade_2015','Retail trade_2015', 'Transportation and warehousing, and utilities_2015','Information_2015','Finance and insurance, and real estate and rental and leasing_2015', 'Professional, scientific, and management, and administrative and waste management services_2015','Educational services, and health care and social assistance_2015','Arts, entertainment, and recreation, and accommodation and food services_2015','Other services, except public administration_2015','Public administration_2015']]
y = data_new['2015_Binning']

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
print(vif_data)
# Out:
#                                               feature        VIF
# 0   Agriculture, forestry, fishing and hunting, an...   1.756315
# 1                                   Construction_2015  17.023297
# 2                                  Manufacturing_2015   5.535015
# 3                                Wholesale trade_2015  13.756516
# 4                                   Retail trade_2015  48.026023
# 5   Transportation and warehousing, and utilities_...  10.806648
# 6                                    Information_2015  11.762493
# 7   Finance and insurance, and real estate and ren...  12.599692
# 8   Professional, scientific, and management, and ...  23.589361
# 9   Educational services, and health care and soci...  23.514338
# 10  Arts, entertainment, and recreation, and accom...  15.521685
# 11  Other services, except public administration_2015  32.156676
# 12                         Public administration_2015   5.394275

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=100)

from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=2, random_state=2)
clf.fit(x_train, y_train)

#Prediction of test set
y_pred= clf.predict(x_test)

# import export_graphviz
from sklearn.tree import export_graphviz 
  
# export the decision tree to a tree.dot file
# for visualizing the plot easily anywhere
export_graphviz(clf, out_file ='tree2015.dot') 

from sklearn import metrics
meanAbErr = metrics.mean_absolute_error(y_test, y_pred)
meanSqErr = metrics.mean_squared_error(y_test, y_pred)
rootMeanSqErr = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('R squared: {:.2f}'.format(clf.score(x_test,y_test)))
print('Mean Absolute Error:', meanAbErr)
print('Mean Square Error:', meanSqErr)
print('Root Mean Square Error:', rootMeanSqErr)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# R squared: 0.83
# Mean Absolute Error: 0.19444444444444445
# Mean Square Error: 0.2638888888888889
# Root Mean Square Error: 0.5137011669140814
# Accuracy: 0.8333333333333334

# %%
x = data_new[['Agriculture, forestry, fishing and hunting, and mining_2019','Construction_2019','Manufacturing_2019','Wholesale trade_2019','Retail trade_2019', 'Transportation and warehousing, and utilities_2019','Information_2019','Finance and insurance, and real estate and rental and leasing_2019', 'Professional, scientific, and management, and administrative and waste management services_2019','Educational services, and health care and social assistance_2019','Arts, entertainment, and recreation, and accommodation and food services_2019','Other services, except public administration_2019','Public administration_2019']]
y = data_new['2019_Binning']

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
print(vif_data)
# Out:
#                                               feature        VIF
# 0   Agriculture, forestry, fishing and hunting, an...   1.705317
# 1                                   Construction_2019  16.924155
# 2                                  Manufacturing_2019   5.763288
# 3                                Wholesale trade_2019  13.255246
# 4                                   Retail trade_2019  46.507569
# 5   Transportation and warehousing, and utilities_...   9.876562
# 6                                    Information_2019   9.108604
# 7   Finance and insurance, and real estate and ren...  12.724922
# 8   Professional, scientific, and management, and ...  19.441753
# 9   Educational services, and health care and soci...  23.960207
# 10  Arts, entertainment, and recreation, and accom...  15.605284
# 11  Other services, except public administration_2019  25.649430
# 12                         Public administration_2019   5.515734

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=100)

from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=2, random_state=2)
clf.fit(x_train, y_train)

#Prediction of test set
y_pred= clf.predict(x_test)

# import export_graphviz
from sklearn.tree import export_graphviz 
  
# export the decision tree to a tree.dot file
# for visualizing the plot easily anywhere
export_graphviz(clf, out_file ='tree2019.dot') 

from sklearn import metrics
meanAbErr = metrics.mean_absolute_error(y_test, y_pred)
meanSqErr = metrics.mean_squared_error(y_test, y_pred)
rootMeanSqErr = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('R squared: {:.2f}'.format(clf.score(x_test,y_test)))
print('Mean Absolute Error:', meanAbErr)
print('Mean Square Error:', meanSqErr)
print('Root Mean Square Error:', rootMeanSqErr)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16716\2786838095.py in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=100)
#       3
#       4 from sklearn.tree import DecisionTreeClassifier
#       5 clf = DecisionTreeClassifier(max_depth=2, random_state=2)
#
# NameError: name 'x' is not defined

# %%
print(data_new.columns[2:15])

# %%
print(data_new.columns[16:29])

# %%
print(data_new.columns[30:43])
