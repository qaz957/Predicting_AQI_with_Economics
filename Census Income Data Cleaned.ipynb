# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
Income = pd.read_csv('Income_by_County.csv', delimiter=',',index_col=None) 

Income.head(10)
# Out:
#                County Name              Label _Grouping   Total  \
# 0                      NaN                          NaN     NaN
# 1  Autauga County, Alabama      Autauga County, Alabama     NaN
# 2  Autauga County, Alabama                   Households  21,559
# 3  Autauga County, Alabama                     Estimate     NaN
# 4  Autauga County, Alabama                     Families  15,103
# 5  Autauga County, Alabama                     Estimate     NaN
# 6  Autauga County, Alabama      Married-couple families  11,281
# 7  Autauga County, Alabama                     Estimate     NaN
# 8  Autauga County, Alabama         Nonfamily households   6,456
# 9  Autauga County, Alabama                     Estimate     NaN
#
#   Total Less than $10,000 Total $10,000 to $14,999 Total 15,000 to $24,999  \
# 0                     NaN                      NaN                     NaN
# 1                     NaN                      NaN                     NaN
# ...

# %%
# DROP NaN VALUES FROM DATA
Drop_NA = Income.dropna(subset=['Total'])

Drop_NA.head(10)
# Out:
#                 County Name              Label _Grouping   Total  \
# 2   Autauga County, Alabama                   Households  21,559
# 4   Autauga County, Alabama                     Families  15,103
# 6   Autauga County, Alabama      Married-couple families  11,281
# 8   Autauga County, Alabama         Nonfamily households   6,456
# 11  Baldwin County, Alabama                   Households  84,047
# 13  Baldwin County, Alabama                     Families  56,092
# 15  Baldwin County, Alabama      Married-couple families  46,277
# 17  Baldwin County, Alabama         Nonfamily households  27,955
# 20  Barbour County, Alabama                   Households   9,322
# 22  Barbour County, Alabama                     Families   6,083
#
#    Total Less than $10,000 Total $10,000 to $14,999 Total 15,000 to $24,999  \
# 2                    6.20%                    4.60%                  12.30%
# 4                    5.20%                    2.60%                   8.10%
# ...

# %%
Cleaned_Census = Drop_NA

# %%
Cleaned_Census.to_csv('Cleaned_Income_Data.csv', index=False)
